# %%
plt.figure(figsize=[16,12])
from sklearn.metrics import roc_curve, roc_auc_score 
models = [
    {
        'label': 'Bagging Classifier',
        'model': bag,
    },
        {
        'label': 'Random Forest',
        'model': rf,
    },
    {
        'label': 'Support Vector Machine',
        'model': svc,
    },
    {
        'label': 'Decision Tree',
        'model': dt,
    },
    {
        'label': 'Bernoulli',
        'model': ber,
    },
    {
        'label': 'Gradient Boosting Classifier',
        'model': gradb,
    },
    {
        'label': 'XGBoost',
        'model': xgb,
    },
    {
        'label': 'Logistic Regression',
        'model': logr,
    },
    {
        'label': 'AdaBoost',
        'model': ada,
    },

]


for i in models:
    model = i['model']
    model.fit(train_features, train_y) # train the model
    y_pred = model.predict(valid_features) #predicting the validation data

    # computing false positive and true positive rate
    fpr, tpr, thresholds = roc_curve(valid_y, model.predict_proba(valid_features)[:,1])

    #calculating area under the curve to display on the plot
    auc = roc_auc_score(valid_y, model.predict(valid_features))
    
    #plot the computed values
    plt.plot(fpr, tpr, label='%a ROC (area = %0.2f)'%(i['label'], auc))

#Settings for plot
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('FPR (1-Specificity)')
plt.ylabel('TPR(Sensitivity)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
